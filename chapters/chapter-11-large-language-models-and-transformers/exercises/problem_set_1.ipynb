# %% [markdown]
# # Chapter 11 — Problem Set 1: Transformer Architecture
#
# Exercises align with **Notebook 01**. Complete each problem; full solutions are in `solutions/problem_set_1_solutions.ipynb`.
#
# Run this cell first to set up imports.

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..', 'scripts'))
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)

# %% [markdown]
# ## 1. Implement Scaled Dot-Product Attention
#
# Write a function `my_sdp_attention(Q, K, V)` that returns `(output, weights)` matching:
#
# $$\text{Attention}(Q,K,V) = \text{softmax}\!\left(\frac{QK^\top}{\sqrt{d_k}}\right)V$$
#
# - Use a **numerically stable softmax**.
# - Verify your output against `transformer_utils.scaled_dot_product_attention` on random `(Q, K, V)` of shape `(6, 8)`.

# %%
# Your code here
def my_sdp_attention(Q, K, V):
    pass

# %% [markdown]
# ## 2. Build Sinusoidal Positional Encoding
#
# Implement `my_positional_encoding(seq_len, d_model)` so that:
#
# - Even dimensions use `sin`, odd dimensions use `cos`.
# - The wavelengths form a geometric progression from `2π` to `2π · 10000`.
# - Output shape is `(seq_len, d_model)`.
#
# Plot the encoding as a heatmap and verify column 0 is a sine wave.

# %%
# Your code here
def my_positional_encoding(seq_len, d_model):
    pass

# %% [markdown]
# ## 3. Plot an Attention Heatmap
#
# Take three sentences with shared topics, build random Q/K/V, run self-attention, and **plot the attention weights** with token labels on the axes. Comment on which positions attend to which.

# %%
# Your code here

# %% [markdown]
# ## 4. Tokenize Text & Reason About BPE
#
# - Tokenize `"unbelievably preprocessed"` with `transformers.AutoTokenizer` (or fall back to manual split if not installed).
# - Identify which tokens are **continuation pieces** (e.g. `##ly`, `Ġprocessed`).
# - Explain in one sentence why BPE never produces an out-of-vocabulary error.

# %%
# Your code here

# %% [markdown]
# ## 5. Multi-Head Attention Shape Check
#
# Given `d_model=64`, `num_heads=8`, `seq_len=10`, `batch=2`:
#
# - Build a `MultiHeadAttention` and run it.
# - Print every shape: `Q/K/V` after splitting heads, attention weights, and the final output.
# - Verify `d_head * num_heads == d_model`.

# %%
# Your code here

# %% [markdown]
# ## 6. Compare Encoder / Decoder / Encoder–Decoder
#
# Fill in the table for these tasks. Pick **the one most natural family** and justify in one line each.
#
# | Task | Family (encoder / decoder / enc-dec) | Why |
# |------|--------------------------------------|-----|
# | Sentiment classification | ? | ? |
# | Story continuation | ? | ? |
# | English → French translation | ? | ? |
# | Document summarisation | ? | ? |
# | Named-entity extraction | ? | ? |

# %%
# Your code here (you may answer in a comment block)
