# %% [markdown]
# # Chapter 10 — Problem Set 2: Classification & NER
#
# Exercises align with **Notebook 02**. Solutions are in `solutions/problem_set_2_solutions.ipynb`.
#
# ---
# *Generated by Berta AI*

# %% [markdown]
# ## 1. Deep Learning Text Classification
#
# - Build an **LSTM** (or 1D CNN) for text classification using Keras/TensorFlow or PyTorch.
# - Use embeddings (random or pre-trained) and pad sequences.
# - Compare **CNN vs LSTM** on the same dataset (accuracy/F1, training time).
# - Tune at least one **hyperparameter** (e.g. units, dropout).

# %%
# Your code here

# %% [markdown]
# ## 2. Named Entity Recognition
#
# - Use **spaCy NER** to extract entities from 5–10 sentences (mix of PERSON, ORG, GPE).
# - Evaluate: compare model output to **ner_examples.txt** or your own annotations (precision/recall per type).
# - Analyze **errors**: false positives, false negatives, boundary mistakes.

# %%
# Your code here

# %% [markdown]
# ## 3. Document Clustering
#
# - Cluster documents (e.g. **news_categories.csv**) using **K-Means** on TF-IDF vectors.
# - Evaluate: **silhouette score** or compare cluster labels to true categories (if available).
# - **Visualize** clusters in 2D (e.g. PCA or t-SNE on TF-IDF).

# %%
# Your code here

# %% [markdown]
# ## 4. Sentiment with Deep Learning
#
# - Train a **neural network** (e.g. LSTM or small MLP on TF-IDF) for sentiment.
# - Add **regularization** (dropout, L2).
# - Compare with **traditional** (logistic regression on TF-IDF): accuracy and training time.

# %%
# Your code here

# %% [markdown]
# ## 5. Multi-task Learning
#
# - From the **same text**, predict both **sentiment** and a **category** (e.g. topic).
# - Use **shared embeddings** or shared TF-IDF features with two heads.
# - Report per-task metrics and discuss **trade-offs** (e.g. one task hurting the other).

# %%
# Your code here

# %% [markdown]
# ## 6. Text Similarity Search
#
# - Build a **search** that returns the most similar documents to a query from a corpus.
# - Use TF-IDF + cosine similarity (or embedding similarity).
# - Evaluate: on a few queries, check if top results are relevant; optionally measure **retrieval quality** (e.g. if you have labels).

# %%
# Your code here

# %% [markdown]
# ## 7. Language Model Fine-tuning Preview
#
# - If **transformers** is installed: **fine-tune** a small BERT/DistilBERT on a classification task (e.g. sentiment or news category).
# - Compare to **CNN/LSTM** from scratch: accuracy and **computational cost** (time, memory).
# - Write 2–3 sentences on when you would choose fine-tuned BERT vs. a lighter model.

# %%
# Your code here
