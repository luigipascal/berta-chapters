# %% [markdown]
# # Chapter 12 — Problem Set 1: Prompt Basics
#
# Exercises align with **Notebook 01**. Complete each exercise; solutions are in `solutions/problem_set_1_solutions.ipynb`.
#
# All exercises run **offline** with the bundled `MockLLMClient`.
#
# ---
# *Generated by Berta AI*

# %% [markdown]
# ## 1. Rewrite a Vague Prompt
#
# The prompt below is **vague**. Rewrite it so the model has clear instructions, an explicit output spec, and (optionally) one example. Use a `PromptTemplate` and run it through the mock client.
#
# ```
# Tell me about this review: "The phone is fast but the battery dies quickly."
# ```

# %%
# Your code here

# %% [markdown]
# ## 2. Build Few-Shot Examples
#
# Pick a small task (e.g. classify a headline as `tech`/`sports`/`politics`/`entertainment`). Build a `FewShotTemplate` with **3 examples** and classify two new headlines.

# %%
# Your code here

# %% [markdown]
# ## 3. Design a Structured-Output Schema
#
# Define a Pydantic schema for a **product review extractor** with fields: `product_name: str`, `rating: int` (1–5), `pros: list[str]`, `cons: list[str]`. Build the prompt directly from the schema and parse the result with `safe_json_parse`.

# %%
# Your code here

# %% [markdown]
# ## 4. Classify a Tricky Example
#
# Use one of your sentiment prompts on this **mixed** review and inspect the output:
#
# > *"The food was amazing but the service was awful."*
#
# Then write **one short sentence** explaining why this is hard for a single-label classifier.

# %%
# Your code here

# %% [markdown]
# ## 5. Count Tokens (Heuristic)
#
# Implement a function `approx_token_count(text)` that returns roughly `len(text) / 4` (a common heuristic for English text). Use it to estimate the token cost of a long prompt. Compare against `MockLLMClient`'s `LLMResponse.prompt_tokens`.

# %%
# Your code here

# %% [markdown]
# ## 6. Parse JSON Safely
#
# The mock model sometimes wraps JSON in prose. Write a function `parse_or_default(raw, schema_cls)` that tries `safe_json_parse` and validates with the Pydantic class; on failure it returns a default instance. Demonstrate it on:
#
# ```
# "Here is your answer: {"label": "positive", "confidence": 0.9}"
# "sorry, I cannot do that"
# ```

# %%
# Your code here

# %% [markdown]
# ---
# *Generated by Berta AI*
